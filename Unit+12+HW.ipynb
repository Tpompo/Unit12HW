# %%
my_list = [45.4,44.2,36.8,35.1,39.0,60.0,47.4,41.1,45.8,35.6]

# %%
my_list[4]
# Out:
# 39.0

# %%
my_list.append(55.2)

# %%
my_list
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 60.0, 47.4, 41.1, 45.8, 35.6, 55.2]

# %%
my_list.pop(5)
# Out:
# 60.0

# %%
my_list
# Out:
# [45.4, 44.2, 36.8, 35.1, 39.0, 47.4, 41.1, 45.8, 35.6, 55.2]

# %%
for value in my_list:
    if value > 45:
        print(value)
# Out:
# 45.4
# 47.4
# 45.8
# 55.2

# %%
import numpy

# %%
a = numpy.array([45.4,44.2,36.8,35.1,39.0,60.0,47.4,41.1,45.8,35.6])

# %%
a
# Out:
# array([ 45.4,  44.2,  36.8,  35.1,  39. ,  60. ,  47.4,  41.1,  45.8,  35.6])

# %%
numpy.mean(a)
# Out:
# 43.040000000000006

# %%
numpy.std(a)
# Out:
# 7.0611897014596625

# %%
for value2 in a:
    if value2 < 45:
        print(value2)
# Out:
# 44.2
# 36.8
# 35.1
# 39.0
# 41.1
# 35.6

# %%
numpy.max(a), numpy.min(a)
# Out:
# (60.0, 35.100000000000001)

# %%
import pandas

# %%
iris = pandas.read_csv("C:/Users/Tpomp/Desktop/Iris.csv")

# %%
iris.head
# Out:
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
df = pandas.DataFrame(iris)

# %%
df.drop("Id", axis = 1)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# 6              4.6           3.4            1.4           0.3     Iris-setosa
# 7              5.0           3.4            1.5           0.2     Iris-setosa
# 8              4.4           2.9            1.4           0.2     Iris-setosa
# 9              4.9           3.1            1.5           0.1     Iris-setosa
# 10             5.4           3.7            1.5           0.2     Iris-setosa
# ...

# %%
setosa = df.query('Species == "Iris-setosa"')

# %%
setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
byspecies = df.groupby('Species')

# %%
byspecies

# %%
byspecies.describe()
# Out:
#                               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa     count   50.00000      50.000000     50.000000      50.000000
#                 mean    25.50000       5.006000      3.418000       1.464000
#                 std     14.57738       0.352490      0.381024       0.173511
#                 min      1.00000       4.300000      2.300000       1.000000
#                 25%     13.25000       4.800000      3.125000       1.400000
#                 50%     25.50000       5.000000      3.400000       1.500000
#                 75%     37.75000       5.200000      3.675000       1.575000
#                 max     50.00000       5.800000      4.400000       1.900000
# Iris-versicolor count   50.00000      50.000000     50.000000      50.000000
#                 mean    75.50000       5.936000      2.770000       4.260000
#                 std     14.57738       0.516171      0.313798       0.469911
# ...

# %%
byspecies.boxplot()
# Out:
# C:\Users\Tpomp\Anaconda3\lib\site-packages\pandas\tools\plotting.py:3082: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   rot=rot, grid=grid, **kwds)
# OrderedDict([('Iris-setosa',
#               {'boxes': [<matplotlib.lines.Line2D at 0x1d57ef55860>,
# ...
#                'caps': [<matplotlib.lines.Line2D at 0x1d57ef90780>,
# ...
#                'fliers': [<matplotlib.lines.Line2D at 0x1d57efa0e48>,
# ...
#                'means': [],
#                'medians': [<matplotlib.lines.Line2D at 0x1d57efa0630>,
# ...
#                'whiskers': [<matplotlib.lines.Line2D at 0x1d57ef94b00>,
# ...
#                 <matplotlib.lines.Line2D at 0x1d57efea978>]}),
#              ('Iris-versicolor',
#               {'boxes': [<matplotlib.lines.Line2D at 0x1d57eff0c18>,
# ...

# %%
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-112-ed9806ce3570> in <module>()
# ----> 1 import seaborn as sns
#
# ImportError: No module named 'seaborn'

# %%
sns.pairplot(iris.hue='Species')
# Out:
#   File "<ipython-input-114-f3970243fa8d>", line 1
#     sns.pairplot(iris.hue='Species')
#                 ^
# SyntaxError: keyword can't be an expression

# %%
# Out:
#   File "<ipython-input-115-e64112ca6522>", line 1
#     git remote add origin https://github.com/Tpompo/Unit12HW.git
#              ^
# SyntaxError: invalid syntax
